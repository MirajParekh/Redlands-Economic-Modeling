# %%
from redlands_simulation import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4716c0478354> in <cell line: 1>()
# ----> 1 from redlands_simulation import *
#
# ModuleNotFoundError: No module named 'redlands_simulation'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# PART 1: Redlands total population from 1990-2022

# %%
plot_estimates_part1()

# %% [markdown]
# PART 1. PT B.: Redlands Total Population from 1990 to 2040

# %%
# plot_estimates_part1_future()
# decorate(title='Redlands Total Population Over Time (T)')
# plt.show()

# %% [markdown]
# PART 2: Number of people in the labor force

# %%
plot_estimates_part2()

# %% [markdown]
# PART 3: Employment (a) and Unemployment from 1990-2022.

# %%
plot_estimates_part3b()
decorate(title='Redlands Total Unemployment Over Time')

# %%
plot_estimates_part3a()
decorate(title='Redlands Total Employment Over Time')

# %% [markdown]
# Part 4: Median income of a population

# %%
plot_estimates_part4()

# %% [markdown]
# Part 5: Poverty Rate

# %%
plot_estimates_part5()

# %% [markdown]
# Combo plot 1: Employed, uneployed, labor force (1990-2022)

# %%
plot_estimates_part6()

# %% [markdown]
# Part 7: Total # of People in Poverty (2011-2022)

# %%
plot_estimates_part7()

# %% [markdown]
# Part 8: Combo

# %%
plot_estimates_part8()

# %%
years_list, impacted_value_list = plot_estimates_part10_algorithm(0.05,0.045,start_indiv_value,recent_change_indiv_income, recent_change_poverty,recent_change_labor,recent_change_pop,recent_change_unemployed,recent_change_employed, 2100)
plot_estimates_part10(years_list, impacted_value_list)
#the farther away from the middle point of 0.05, the more drastic the noise/change

# %% [markdown]
# Combo Graph 3: Projected Income vs Projected Income Considering Inflation

# %%
plot_estimates_part11()
